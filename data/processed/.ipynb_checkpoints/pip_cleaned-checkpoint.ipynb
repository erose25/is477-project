# %%
# %%writefile ../../scripts/pip2024cleaning.py

import pandas as pd
# Out:
# Overwriting ../../scripts/pip2024cleaning.py

# %%
df = pd.read_csv("../raw/pip_dataset.csv")

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2556 entries, 0 to 2555
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   region_name           2556 non-null   object
#  1   region_code           2556 non-null   object
#  2   country_name          2556 non-null   object
#  3   country_code          2556 non-null   object
#  4   reporting_year        2556 non-null   int64
#  5   reporting_level       2556 non-null   object
#  6   survey_acronym        2556 non-null   object
#  7   survey_coverage       2556 non-null   object
#  8   survey_year           2556 non-null   float64
#  9   welfare_type          2556 non-null   object
#  10  survey_comparability  2556 non-null   int64
#  11  comparable_spell      2556 non-null   object
#  12  poverty_line          2556 non-null   int64
#  13  headcount             2556 non-null   float64
#  14  poverty_gap           2556 non-null   float64
#  15  poverty_severity      2556 non-null   float64
#  16  watts                 2547 non-null   float64
#  17  mean                  2556 non-null   float64
#  18  median                2556 non-null   float64
#  19  mld                   2556 non-null   float64
#  20  gini                  2556 non-null   float64
#  21  polarization          2556 non-null   float64
#  22  decile1               2556 non-null   float64
#  23  decile2               2556 non-null   float64
#  24  decile3               2556 non-null   float64
#  25  decile4               2556 non-null   float64
#  26  decile5               2556 non-null   float64
#  27  decile6               2556 non-null   float64
#  28  decile7               2556 non-null   float64
#  29  decile8               2556 non-null   float64
#  30  decile9               2556 non-null   float64
#  31  decile10              2556 non-null   float64
#  32  cpi                   2556 non-null   float64
#  33  ppp                   2533 non-null   float64
#  34  reporting_pop         2556 non-null   float64
#  35  reporting_gdp         2556 non-null   float64
#  36  reporting_pce         2275 non-null   float64
#  37  is_interpolated       2556 non-null   bool
#  38  distribution_type     2556 non-null   object
#  39  estimation_type       2556 non-null   object
#  40  spl                   2556 non-null   float64
#  41  spr                   2556 non-null   float64
#  42  pg                    2556 non-null   float64
#  43  estimate_type         0 non-null      float64
# dtypes: bool(1), float64(29), int64(3), object(11)
# memory usage: 861.3+ KB

# %%
## keeping only relevant rows to our analysis

df = df[[
    "country_code", 
    "country_name",
    "reporting_year",
    "headcount",
    "gini",
]]

# %%
## renaming for future merging 

df = df.rename(columns = {
    "reporting_year" : "year",
    "headcount" : "poverty_headcount"
})

# %%
## dropping the rows with unusual countries like "Sub-Saharan Africa" and "Europe and Central Asia"  

df = df[df["country_code"].notna()]
df = df[df["country_code"].str.len() == 3]

# %%
df.isnull().sum()
# Out:
# country_code         0
# country_name         0
# year                 0
# poverty_headcount    0
# gini                 0
# dtype: int64

# %%
## removing duplicates where we have the same year more than once for the same country 

df = df.drop_duplicates(subset = ["country_code", "year"])

# %%
## ensuring correct data types 

df["year"] = df["year"].astype(int)
df["poverty_headcount"] = df["poverty_headcount"].astype(float)
df["gini"] = df["gini"].astype(float)

df.to_csv("../processed/pip_cleaned_2024.csv", index = False)

# %%
## sort for timeseries

df = df.sort_values(by = ["country_code", "year"])

# %%
## save cleaned dataset

df.to_csv("../processed/pip_cleaned_timeseries.csv", index = False)

# %%
df
# Out:
#      country_code country_name  year  poverty_headcount      gini
# 0             AGO       Angola  2000           0.269546  0.519451
# 1             AGO       Angola  2008           0.220796  0.427155
# 2             AGO       Angola  2018           0.392947  0.512643
# 3             ALB      Albania  1996           0.029678  0.270103
# 4             ALB      Albania  2002           0.041947  0.317390
# ...           ...          ...   ...                ...       ...
# 2551          ZMB       Zambia  2015           0.678928  0.558407
# 2552          ZMB       Zambia  2022           0.716561  0.514849
# 2553          ZWE     Zimbabwe  2011           0.357170  0.431536
# 2554          ZWE     Zimbabwe  2017           0.446569  0.443371
# 2555          ZWE     Zimbabwe  2019           0.492199  0.502565
#
# [2422 rows x 5 columns]

# %%
# !jupyter nbconvert --to script pip_cleaned.ipynb --output-dir='../../scripts/' --output='pip2024cleaning'
# Out:
# [NbConvertApp] Converting notebook pip_cleaned.ipynb to script
# [NbConvertApp] Writing 1410 bytes to ..\..\scripts\pip2024cleaning.py
